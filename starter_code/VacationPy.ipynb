# %% [markdown]
# ###### VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from citipy import citipy


# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     badger  64.8000 -147.5333     25.21        28          20
# 1        1   celestun  20.8667  -90.4000     27.04        78          41
# 2        2  mahajanga -15.7167   46.3167     20.01        77          20
# 3        3   bilibino  68.0546  166.4372     13.57        46         100
# 4        4   fairmont  39.4851  -80.1426     17.51        66           0
#
#    Wind Speed Country        Date
# 0        3.09      US  1686016656
# 1        7.37      MX  1686016657
# 2        1.54      MG  1686016657
# 3        3.46      RU  1686016466
# 4        1.06      US  1686016657

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,  
    size = "Humidity",
    color = "City"
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#For example: o A max temperature lower than 30 degrees but higher than 17 o Wind speed less than 4 m/s o Zero cloudiness 
ideal_weather_df = city_data_df.loc[(city_data_df["Max Temp"]<30)
                                    &(city_data_df["Max Temp"]>18)
                                    &(city_data_df["Wind Speed"]<4)
                                    &(city_data_df["Cloudiness"]==0)]
                                    

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
ideal_weather_df
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 14        14               ad darbasiyah  37.0728   40.6520     22.05
# 16        16                  fort bragg  35.1390  -79.0060     23.23
# 24        24                     matoury   4.8483  -52.3317     24.98
# 40        40                    hamilton  39.1834  -84.5333     20.35
# 41        41                saint-pierre -21.3393   55.4781     21.98
# 82        82                    belmonte -15.8631  -38.8828     22.27
# 92        92                   topchikha  52.8192   83.1185     24.61
# 179      179                   brookings  44.3114  -96.7984     27.00
# 192      192                 novosibirsk  55.0411   82.9344     23.61
# 198      198                  serhetabat  35.2799   62.3438     26.21
# 208      208               mermoz boabab  14.7065  -17.4758     23.88
# 263      263                     bemidji  47.4736  -94.8803     23.05
# 270      270                 zhezqazghan  47.7833   67.7667     24.32
# 320      320                        rota  36.6224   -6.3586     20.68
# 349      349                 le lavandou  43.1370    6.3660     18.20
# 359      359              senador canedo -16.7081  -49.0931     18.63
# 378      378                     uruzgan  32.8333   66.0000     21.78
# 394      394                     mineros -17.1167  -63.2333     21.36
# 397      397                       korla  41.7597   86.1469     27.50
# 400      400                  qala i naw  34.9874   63.1289     25.14
# 402      402                  baker city  44.7749 -117.8344     26.84
# 403      403             remire-montjoly   4.9167  -52.2667     25.02
# 404      404                      najran  17.4924   44.1277     24.36
# 411      411                      pierre  44.3683 -100.3510     27.51
# 438      438                gyeongsan-si  35.8233  128.7378     22.86
# 476      476            pontes e lacerda -15.2261  -59.3353     20.97
# 506      506                     brandon  27.9378  -82.2859     27.93
# 515      515                   belyy yar  53.6039   91.3903     23.94
# 519      519  ust'-charyshskaya pristan'  52.3934   83.6635     24.60
# 524      524                    glendive  47.1053 -104.7125     29.79
# 533      533                     corumba -19.0092  -57.6533     21.80
# 535      535                      abalak  58.1286   68.5944     18.76
# 561      561                 vilamarxant  39.5667   -0.6167     20.00
# 575      575                   cambridge  43.3601  -80.3127     21.63
# 586      586                grand island  40.9250  -98.3420     27.97
# 593      593                     lucknow  26.8500   80.9167     28.99
# 599      599                   morondava -20.2833   44.2833     21.76
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 14         29           0        0.91      SY  1686016658
# 16         67           0        3.60      US  1686016513
# 24         88           0        1.03      GF  1686016660
# 40         48           0        0.00      US  1686016371
# 41         73           0        3.09      RE  1686016662
# 82         74           0        2.21      BR  1686016668
# 92         53           0        2.73      RU  1686016669
# 179        54           0        3.09      US  1686016418
# 192        60           0        0.00      RU  1686016684
# 198        21           0        1.23      TM  1686016685
# 208        88           0        3.09      SN  1686016687
# 263        83           0        0.00      US  1686016696
# 270        29           0        3.00      KZ  1686016697
# 320        88           0        2.06      ES  1686016705
# 349        94           0        1.54      FR  1686016709
# 359        63           0        1.54      BR  1686016711
# 378        23           0        2.53      AF  1686016714
# 394        83           0        1.15      BO  1686016716
# 397        16           0        2.55      CN  1686016717
# 400        18           0        0.75      AF  1686016717
# 402        47           0        3.60      US  1686016718
# 403        88           0        1.03      GF  1686016482
# 404        25           0        1.19      SA  1686016718
# 411        50           0        3.09      US  1686016483
# 438        49           0        2.57      KR  1686016723
# 476        81           0        1.19      BR  1686016728
# 506        70           0        3.60      US  1686016658
# 515        50           0        2.00      RU  1686016734
# 519        57           0        2.85      RU  1686016734
# 524        42           0        3.60      US  1686016735
# 533        64           0        1.25      BR  1686016737
# 535        76           0        2.75      RU  1686016737
# 561        81           0        2.06      ES  1686016742
# 575        63           0        3.09      CA  1686016523
# 586        32           0        3.60      US  1686016634
# 593        61           0        2.06      IN  1686016614
# 599        75           0        3.01      MG  1686016749

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng","Humidity"]]
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API


# Display sample data
# YOUR CODE HERE
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
# C:\Users\dogpl\AppData\Local\Temp\ipykernel_8740\3627056879.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                            City Country      Lat       Lng  Humidity  \
# 14                ad darbasiyah      SY  37.0728   40.6520        29
# 16                   fort bragg      US  35.1390  -79.0060        67
# 24                      matoury      GF   4.8483  -52.3317        88
# 40                     hamilton      US  39.1834  -84.5333        48
# 41                 saint-pierre      RE -21.3393   55.4781        73
# 82                     belmonte      BR -15.8631  -38.8828        74
# 92                    topchikha      RU  52.8192   83.1185        53
# 179                   brookings      US  44.3114  -96.7984        54
# 192                 novosibirsk      RU  55.0411   82.9344        60
# 198                  serhetabat      TM  35.2799   62.3438        21
# 208               mermoz boabab      SN  14.7065  -17.4758        88
# 263                     bemidji      US  47.4736  -94.8803        83
# 270                 zhezqazghan      KZ  47.7833   67.7667        29
# 320                        rota      ES  36.6224   -6.3586        88
# 349                 le lavandou      FR  43.1370    6.3660        94
# 359              senador canedo      BR -16.7081  -49.0931        63
# 378                     uruzgan      AF  32.8333   66.0000        23
# 394                     mineros      BO -17.1167  -63.2333        83
# 397                       korla      CN  41.7597   86.1469        16
# 400                  qala i naw      AF  34.9874   63.1289        18
# 402                  baker city      US  44.7749 -117.8344        47
# 403             remire-montjoly      GF   4.9167  -52.2667        88
# 404                      najran      SA  17.4924   44.1277        25
# 411                      pierre      US  44.3683 -100.3510        50
# 438                gyeongsan-si      KR  35.8233  128.7378        49
# 476            pontes e lacerda      BR -15.2261  -59.3353        81
# 506                     brandon      US  27.9378  -82.2859        70
# 515                   belyy yar      RU  53.6039   91.3903        50
# 519  ust'-charyshskaya pristan'      RU  52.3934   83.6635        57
# 524                    glendive      US  47.1053 -104.7125        42
# 533                     corumba      BR -19.0092  -57.6533        64
# 535                      abalak      RU  58.1286   68.5944        76
# 561                 vilamarxant      ES  39.5667   -0.6167        81
# 575                   cambridge      CA  43.3601  -80.3127        63
# 586                grand island      US  40.9250  -98.3420        32
# 593                     lucknow      IN  26.8500   80.9167        61
# 599                   morondava      MG -20.2833   44.2833        75
#
#     Hotel Name
# 14
# 16
# 24
# 40
# 41
# 82
# 92
# 179
# 192
# 198
# 208
# 263
# 270
# 320
# 349
# 359
# 378
# 394
# 397
# 400
# 402
# 403
# 404
# 411
# 438
# 476
# 506
# 515
# 519
# 524
# 533
# 535
# 561
# 575
# 586
# 593
# 599

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories":"accommodation.hotel",
            "limit": 20,
            "apiKey":geoapify_key    
}
    

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address =  requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ad darbasiyah - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# matoury - nearest hotel: La Marmotte
# hamilton - nearest hotel: North Vista Manor
# saint-pierre - nearest hotel: Tropic Hotel
# belmonte - nearest hotel: No hotel found
# topchikha - nearest hotel: No hotel found
# brookings - nearest hotel: Quality Inn
# novosibirsk - nearest hotel: Apartville
# serhetabat - nearest hotel: No hotel found
# mermoz boabab - nearest hotel: Le Shéhérazade
# bemidji - nearest hotel: Hampton Inn and Suites
# zhezqazghan - nearest hotel: No hotel found
# rota - nearest hotel: Hotel Duque de Nájera
# le lavandou - nearest hotel: Le Terminus
# senador canedo - nearest hotel: No hotel found
# uruzgan - nearest hotel: No hotel found
# mineros - nearest hotel: No hotel found
# korla - nearest hotel: Silver Star Hotel
# qala i naw - nearest hotel: No hotel found
# baker city - nearest hotel: Geiser Grand Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# najran - nearest hotel: No hotel found
# pierre - nearest hotel: Quality Inn
# gyeongsan-si - nearest hotel: SB호텔
# pontes e lacerda - nearest hotel: Hotel Avenida
# brandon - nearest hotel: Brandon Motor Lodge
# belyy yar - nearest hotel: No hotel found
# ust'-charyshskaya pristan' - nearest hotel: Гостиница
# glendive - nearest hotel: La Quinta Inn & Suites by Wyndham Glendive
# corumba - nearest hotel: Hotel El Shadday
# abalak - nearest hotel: No hotel found
# vilamarxant - nearest hotel: Hotel Mas de Canicattí
# cambridge - nearest hotel: Travelodge
# grand island - nearest hotel: Grand Island Travelodge
# lucknow - nearest hotel: Central Hotel
# morondava - nearest hotel: Hotel Sharon Menabe
#                            City Country      Lat       Lng  Humidity  \
# 14                ad darbasiyah      SY  37.0728   40.6520        29
# 16                   fort bragg      US  35.1390  -79.0060        67
# 24                      matoury      GF   4.8483  -52.3317        88
# 40                     hamilton      US  39.1834  -84.5333        48
# 41                 saint-pierre      RE -21.3393   55.4781        73
# 82                     belmonte      BR -15.8631  -38.8828        74
# 92                    topchikha      RU  52.8192   83.1185        53
# 179                   brookings      US  44.3114  -96.7984        54
# 192                 novosibirsk      RU  55.0411   82.9344        60
# 198                  serhetabat      TM  35.2799   62.3438        21
# 208               mermoz boabab      SN  14.7065  -17.4758        88
# 263                     bemidji      US  47.4736  -94.8803        83
# 270                 zhezqazghan      KZ  47.7833   67.7667        29
# 320                        rota      ES  36.6224   -6.3586        88
# 349                 le lavandou      FR  43.1370    6.3660        94
# 359              senador canedo      BR -16.7081  -49.0931        63
# 378                     uruzgan      AF  32.8333   66.0000        23
# 394                     mineros      BO -17.1167  -63.2333        83
# 397                       korla      CN  41.7597   86.1469        16
# 400                  qala i naw      AF  34.9874   63.1289        18
# 402                  baker city      US  44.7749 -117.8344        47
# 403             remire-montjoly      GF   4.9167  -52.2667        88
# 404                      najran      SA  17.4924   44.1277        25
# 411                      pierre      US  44.3683 -100.3510        50
# 438                gyeongsan-si      KR  35.8233  128.7378        49
# 476            pontes e lacerda      BR -15.2261  -59.3353        81
# 506                     brandon      US  27.9378  -82.2859        70
# 515                   belyy yar      RU  53.6039   91.3903        50
# 519  ust'-charyshskaya pristan'      RU  52.3934   83.6635        57
# 524                    glendive      US  47.1053 -104.7125        42
# 533                     corumba      BR -19.0092  -57.6533        64
# 535                      abalak      RU  58.1286   68.5944        76
# 561                 vilamarxant      ES  39.5667   -0.6167        81
# 575                   cambridge      CA  43.3601  -80.3127        63
# 586                grand island      US  40.9250  -98.3420        32
# 593                     lucknow      IN  26.8500   80.9167        61
# 599                   morondava      MG -20.2833   44.2833        75
#
#                                      Hotel Name
# 14                               No hotel found
# 16                         Airborne Inn Lodging
# 24                                  La Marmotte
# 40                            North Vista Manor
# 41                                 Tropic Hotel
# 82                               No hotel found
# 92                               No hotel found
# 179                                 Quality Inn
# 192                                  Apartville
# 198                              No hotel found
# 208                              Le Shéhérazade
# 263                      Hampton Inn and Suites
# 270                              No hotel found
# 320                       Hotel Duque de Nájera
# 349                                 Le Terminus
# 359                              No hotel found
# 378                              No hotel found
# 394                              No hotel found
# 397                           Silver Star Hotel
# 400                              No hotel found
# 402                          Geiser Grand Hotel
# 403                             Complexe Belova
# 404                              No hotel found
# 411                                 Quality Inn
# 438                                        SB호텔
# 476                               Hotel Avenida
# 506                         Brandon Motor Lodge
# 515                              No hotel found
# 519                                   Гостиница
# 524  La Quinta Inn & Suites by Wyndham Glendive
# 533                            Hotel El Shadday
# 535                              No hotel found
# 561                      Hotel Mas de Canicattí
# 575                                  Travelodge
# 586                     Grand Island Travelodge
# 593                               Central Hotel
# 599                         Hotel Sharon Menabe

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories":"accommodation.hotel",
            "limit": 20,
            "apiKey":geoapify_key    
}
    

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address =  requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ad darbasiyah - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# matoury - nearest hotel: La Marmotte
# hamilton - nearest hotel: North Vista Manor
# saint-pierre - nearest hotel: Tropic Hotel
# belmonte - nearest hotel: No hotel found
# topchikha - nearest hotel: No hotel found
# brookings - nearest hotel: Quality Inn
# novosibirsk - nearest hotel: Apartville
# serhetabat - nearest hotel: No hotel found
# mermoz boabab - nearest hotel: Le Shéhérazade
# bemidji - nearest hotel: Hampton Inn and Suites
# zhezqazghan - nearest hotel: No hotel found
# rota - nearest hotel: Hotel Duque de Nájera
# le lavandou - nearest hotel: Le Terminus
# senador canedo - nearest hotel: No hotel found
# uruzgan - nearest hotel: No hotel found
# mineros - nearest hotel: No hotel found
# korla - nearest hotel: Silver Star Hotel
# qala i naw - nearest hotel: No hotel found
# baker city - nearest hotel: Geiser Grand Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# najran - nearest hotel: No hotel found
# pierre - nearest hotel: Quality Inn
# gyeongsan-si - nearest hotel: SB호텔
# pontes e lacerda - nearest hotel: Hotel Avenida
# brandon - nearest hotel: Brandon Motor Lodge
# belyy yar - nearest hotel: No hotel found
# ust'-charyshskaya pristan' - nearest hotel: Гостиница
# glendive - nearest hotel: La Quinta Inn & Suites by Wyndham Glendive
# corumba - nearest hotel: Hotel El Shadday
# abalak - nearest hotel: No hotel found
# vilamarxant - nearest hotel: Hotel Mas de Canicattí
# cambridge - nearest hotel: Travelodge
# grand island - nearest hotel: Grand Island Travelodge
# lucknow - nearest hotel: Central Hotel
# morondava - nearest hotel: Hotel Sharon Menabe
#                            City Country      Lat       Lng  Humidity  \
# 14                ad darbasiyah      SY  37.0728   40.6520        29
# 16                   fort bragg      US  35.1390  -79.0060        67
# 24                      matoury      GF   4.8483  -52.3317        88
# 40                     hamilton      US  39.1834  -84.5333        48
# 41                 saint-pierre      RE -21.3393   55.4781        73
# 82                     belmonte      BR -15.8631  -38.8828        74
# 92                    topchikha      RU  52.8192   83.1185        53
# 179                   brookings      US  44.3114  -96.7984        54
# 192                 novosibirsk      RU  55.0411   82.9344        60
# 198                  serhetabat      TM  35.2799   62.3438        21
# 208               mermoz boabab      SN  14.7065  -17.4758        88
# 263                     bemidji      US  47.4736  -94.8803        83
# 270                 zhezqazghan      KZ  47.7833   67.7667        29
# 320                        rota      ES  36.6224   -6.3586        88
# 349                 le lavandou      FR  43.1370    6.3660        94
# 359              senador canedo      BR -16.7081  -49.0931        63
# 378                     uruzgan      AF  32.8333   66.0000        23
# 394                     mineros      BO -17.1167  -63.2333        83
# 397                       korla      CN  41.7597   86.1469        16
# 400                  qala i naw      AF  34.9874   63.1289        18
# 402                  baker city      US  44.7749 -117.8344        47
# 403             remire-montjoly      GF   4.9167  -52.2667        88
# 404                      najran      SA  17.4924   44.1277        25
# 411                      pierre      US  44.3683 -100.3510        50
# 438                gyeongsan-si      KR  35.8233  128.7378        49
# 476            pontes e lacerda      BR -15.2261  -59.3353        81
# 506                     brandon      US  27.9378  -82.2859        70
# 515                   belyy yar      RU  53.6039   91.3903        50
# 519  ust'-charyshskaya pristan'      RU  52.3934   83.6635        57
# 524                    glendive      US  47.1053 -104.7125        42
# 533                     corumba      BR -19.0092  -57.6533        64
# 535                      abalak      RU  58.1286   68.5944        76
# 561                 vilamarxant      ES  39.5667   -0.6167        81
# 575                   cambridge      CA  43.3601  -80.3127        63
# 586                grand island      US  40.9250  -98.3420        32
# 593                     lucknow      IN  26.8500   80.9167        61
# 599                   morondava      MG -20.2833   44.2833        75
#
#                                      Hotel Name
# 14                               No hotel found
# 16                         Airborne Inn Lodging
# 24                                  La Marmotte
# 40                            North Vista Manor
# 41                                 Tropic Hotel
# 82                               No hotel found
# 92                               No hotel found
# 179                                 Quality Inn
# 192                                  Apartville
# 198                              No hotel found
# 208                              Le Shéhérazade
# 263                      Hampton Inn and Suites
# 270                              No hotel found
# 320                       Hotel Duque de Nájera
# 349                                 Le Terminus
# 359                              No hotel found
# 378                              No hotel found
# 394                              No hotel found
# 397                           Silver Star Hotel
# 400                              No hotel found
# 402                          Geiser Grand Hotel
# 403                             Complexe Belova
# 404                              No hotel found
# 411                                 Quality Inn
# 438                                        SB호텔
# 476                               Hotel Avenida
# 506                         Brandon Motor Lodge
# 515                              No hotel found
# 519                                   Гостиница
# 524  La Quinta Inn & Suites by Wyndham Glendive
# 533                            Hotel El Shadday
# 535                              No hotel found
# 561                      Hotel Mas de Canicattí
# 575                                  Travelodge
# 586                     Grand Island Travelodge
# 593                               Central Hotel
# 599                         Hotel Sharon Menabe

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,  
    size = "Humidity",
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
